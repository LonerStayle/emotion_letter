# %% [markdown]
# # EasyOCR

# %% [markdown]
# `uv add easyocr`

# %%
import cv2
import easyocr

# 한국어 + 영어 모델 로드
reader = easyocr.Reader(["ko", "en"])
img_path = "C:/emotion_letter/app/tests/data/sample_letter3.jpg"
# OCR 실행
results = reader.readtext(img_path)

# 이미지 불러오기 (RGB 변환)
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

for bbox, text, prob in results:
    print(f"인식 결과: {text} (신뢰도 {prob:.2f})")
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# c:\emotion_letter\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# 인식 결과: 안념 (신뢰도 0.95)
# 인식 결과: 나요재야. 이 (신뢰도 0.27)
# 인식 결과: OCK 7et률 위해 쓰는 편지야: (신뢰도 0.13)
# 인식 결과: 효재가- (신뢰도 0.54)
# 인식 결과: 누머지 (신뢰도 0.05)

# %% [markdown]
# # 결과 시각화

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import koreanize_matplotlib
import easyocr

# EasyOCR 로드
reader = easyocr.Reader(["ko", "en"])
img_path = "C:/emotion_letter/app/tests/data/sample_letter3.jpg"

# OCR 실행
results = reader.readtext(img_path)

# 이미지 불러오기 (RGB 변환)
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# OCR 결과 그리기
for bbox, text, prob in results:
    pts = np.array(bbox).astype(int)
    cv2.polylines(img, [pts], isClosed=True, color=(0, 255, 0), thickness=2)
    cv2.putText(
        img,
        text,
        tuple(pts[0]),
        cv2.FONT_HERSHEY_SIMPLEX,
        0.8,
        (255, 0, 0),
        2,
        cv2.LINE_AA,
    )

# 시각화
plt.figure(figsize=(12, 8))
plt.imshow(img)
plt.title("손글씨 OCR 결과 (EasyOCR)")
plt.axis("off")
plt.show()
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# c:\emotion_letter\.venv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
